# %% [markdown]
# <a href="https://colab.research.google.com/github/Devansh0907/AI-Voice-Interview-Agent/blob/main/runnables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

class nakilllm:

    def predict(self, prompt):

        response_list = [
            'Delhi is the capital of India',
            'IPL is a cricket league',
            'AI stands for Artificial Intelligence',
            'Paris is the capital of France'
        ]

        return {'response': random.choice(response_list)}

llm = nakilllm()

print(llm.predict('What is the capital of india'))
# Out:
# {'response': 'Paris is the capital of France'}

# %%
llm.predict('What is the captital of india')
# Out:
# {'response': 'Delhi is the capital of India'}

# %%
class NakliPrompt:

    def __init__(self, template, input_variables):
        self.template = template
        self.input_variables = input_variables

    def format(self, input_dict):
        return self.template.format(**input_dict)


template = NakliPrompt(
    template='What is the capital of {country}',
    input_variables=['country']
)

print(template.format({'country': 'India'}))
# Out:
# What is the capital of India
