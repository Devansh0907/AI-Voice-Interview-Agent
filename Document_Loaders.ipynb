# %% [markdown]
# <a href="https://colab.research.google.com/github/Devansh0907/AI-Voice-Interview-Agent/blob/main/Document_Loaders.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install PyYAML

# %%
pip install langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 51.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 5.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# ...

# %%
# !pip install langchain-community pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.9/343.9 kB 2.5 MB/s eta 0:00:00
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader

print("Import successful")
# Out:
# /tmp/ipykernel_7584/4150264707.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader
# Import successful

# %%
loader=PyPDFLoader('dev.pdf')
docs=loader.load()
print(docs)
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-05-09T09:54:22+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-05-09T09:54:22+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': 'dev.pdf', 'total_pages': 6, 'page': 0, 'page_label': '1'}, page_content='CS7015 Deep Learning Lecture 23 - Generative\n Adversarial Networks (GANs)\nThese notes summarize Lecture 23 of CS7015 Deep Learning by Mitesh M. Khapra. The lecture introduces\nGenerative Adversarial Networks (GANs), explains the intuition, generator-discriminator framework, minimax objective\nfunction, GAN training algorithm, and Deep Convolutional GAN (DCGAN) architectures.\n1. Introduction to Generative Models\nPreviously studied generative models:\n- Restricted Boltzmann Machines (RBMs)\n- Variational Autoencoders (VAEs)\n- Autoregressive (AR) Models\nThese models explicitly learn:\n- Joint probabi
# ...

# %%
docs[0]
# Out:
# Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-05-09T09:54:22+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-05-09T09:54:22+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': 'dev.pdf', 'total_pages': 6, 'page': 0, 'page_label': '1'}, page_content='CS7015 Deep Learning Lecture 23 - Generative\n Adversarial Networks (GANs)\nThese notes summarize Lecture 23 of CS7015 Deep Learning by Mitesh M. Khapra. The lecture introduces\nGenerative Adversarial Networks (GANs), explains the intuition, generator-discriminator framework, minimax objective\nfunction, GAN training algorithm, and Deep Convolutional GAN (DCGAN) architectures.\n1. Introduction to Generative Models\nPreviously studied generative models:\n- Restricted Boltzmann Machines (RBMs)\n- Variational Autoencoders (VAEs)\n- Autoregressive (AR) Models\nThese models explicitly learn:\n- Joint probabil
# ...

# %%
print(len(docs))
# Out:
# 6
